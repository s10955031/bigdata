# %% [markdown]
# <a href="https://colab.research.google.com/github/s10955031/bigdata/blob/main/0420%E6%9C%9F%E4%B8%AD%E8%80%83.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("ggplot2")
install.packages("SportsAnalytics")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(ggplot2)
library(SportsAnalytics)

# %%
NBA1718 <- fetch_NBAPlayerStatistics("17-18")

# %%
NBA1718OrderM<-NBA1718[order(NBA1718$TotalMinutesPlayed,decreasing = T),]
NBA1718OrderM[1:20,"Name"]
# Out:
#  [1] "Lebron James"     "Khris Middleton"  "Andrew Wiggins"   "Bradley Beal"
#  [5] "Jrue Holiday"     "Cj Mccollum"      "Karl-antho Towns" "Russel Westbrook"
#  [9] "Paul George"      "Gi Antetokounmpo" "Anthony Davis"    "Kemba Walker"
# [13] "Ben Simmons"      "Taj Gibson"       "Demar Derozan"    "Josh Richardson"
# [17] "Will Barton"      "Damian Lillard"   "Tobias Harris"    "Donovan Mitchell"

# %%
NBA1718OrderM<-NBA1718[order(NBA1718$GamesPlayed,decreasing = T),]
NBA1718OrderM[1:20,]
# Out:
#     League Name             Team Position GamesPlayed TotalMinutesPlayed
# 37  NBA    Bradley Beal     WAS  SG       82          2977
# 43  NBA    Dragan Bender    PHO  PF       82          2068
# 48  NBA    Bismack Biyombo  ORL  C        82          1491
# 66  NBA    Dillon Brooks    MEM  SF       82          2352
# 108 NBA    Pat Connaughton  POR  SG       82          1490
# 159 NBA    Raymond Felton   OKL  PG       82          1362
# 161 NBA    Yogi Ferrell     DAL  PG       82          2279
# 177 NBA    Taj Gibson       MIN  PF       82          2721
# 182 NBA    Marcin Gortat    WAS  C        82          2078
# 236 NBA    Joe Ingles       UTA  SF       82          2577
# 248 NBA    Lebron James     CLE  SF       82          3024
# 267 NBA    Tyus Jones       MIN  PG       82          1464
# 269 NBA    Cory Joseph      IND  PG       82          2209
# 336 NBA    Khris Middleton  MIL  SF       82          2980
# 338 NBA    Darius Miller    NOR  SF       82          1945
# ...

# %%
subset(NBA1718,Team=="MIN")
# Out:
#     League Name             Team Position GamesPlayed TotalMinutesPlayed
# 6   NBA    Cole Aldrich     MIN  C        21            51
# 49  NBA    Nemanja Bjelica  MIN  PF       67          1372
# 65  NBA    Aaron Brooks     MIN  PG       30           188
# 68  NBA    Anthony Brown    MIN  SF        1             4
# 79  NBA    Jimmy Butler     MIN  SF       59          2160
# 117 NBA    Jamal Crawford   MIN  SG       80          1654
# 133 NBA    Gorgui Dieng     MIN  C        79          1332
# 175 NBA    Mar Georges-hunt MIN  SG       40           226
# 177 NBA    Taj Gibson       MIN  PF       82          2721
# 267 NBA    Tyus Jones       MIN  PG       82          1464
# 394 NBA    Justin Patton    MIN  C         1             4
# 434 NBA    Derrick Rose     MIN  PG       25           420
# 471 NBA    Jeff Teague      MIN  NA       70          2313
# 484 NBA    Karl-antho Towns MIN  C        82          2920
# 514 NBA    Andrew Wiggins   MIN  SG       82          2979
# ...

# %%
subset(NBA1718,Position=="PF")
# Out:
#     League Name             Team Position GamesPlayed TotalMinutesPlayed
# 4   NBA    Bam Adebayo      MIA  PF       69          1369
# 7   NBA    Lamarcu Aldridge SAN  PF       75          2512
# 14  NBA    Ryan Anderson    HOU  PF       66          1727
# 21  NBA    Darrell Arthur   DEN  PF       17           141
# 25  NBA    Luke Babbitt     MIA  PF       49           717
# 41  NBA    Jordan Bell      GSW  PF       56           808
# 43  NBA    Dragan Bender    PHO  PF       82          2068
# 49  NBA    Nemanja Bjelica  MIN  PF       67          1372
# 57  NBA    Joel Bolomboy    MIL  PF        6            37
# 59  NBA    Trevor Booker    IND  PF       68          1164
# 60  NBA    Chris Boucher    GSW  PF        1             1
# 70  NBA    Jaylen Brown     BOS  PF       70          2154
# 92  NBA    Tyler Cavanaugh  ATL  PF       37           521
# 96  NBA    Marquese Chriss  PHO  PF       72          1521
# 102 NBA    John Collins     ATL  PF       74          1784
# ...

# %%
NBA1718[grepl("Davis",NBA1718$Name),]
# Out:
#     League Name          Team Position GamesPlayed TotalMinutesPlayed
# 44  NBA    Davis Bertans SAN  SF       76          1085
# 123 NBA    Anthony Davis NOR  PF       75          2740
# 124 NBA    Deyonta Davis MEM  C        62           941
# 125 NBA    Ed Davis      POR  PF       78          1468
#     FieldGoalsMade FieldGoalsAttempted ThreesMade ThreesAttempted ⋯ Steals
# 44  161             365                94         251             ⋯  27
# 123 780            1462                55         161             ⋯ 115
# 124 161             265                 0           0             ⋯  15
# 125 170             292                 0           1             ⋯  31
#     Turnovers Blocks PersonalFouls Disqualifications TotalPoints Technicals
# 44   36        29     93           0                  456        0
# 123 162       191    159           2                 2110        5
# 124  31        39    125           0                  360        0
# ...

# %%
qplot(FieldGoalsAttempted, TotalPoints, data = NBA1718,color=Position)
# Out:
# plot without title

# %%
qplot(FieldGoalsAttempted, TotalPoints, data = NBA1718,color=Team)
# Out:
# plot without title

# %%
qplot(ThreesAttempted, TotalPoints, data = NBA1718,
   geom = c("point", "smooth"))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
qplot(TotalPoints, data = NBA1718, fill = Position)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
qplot(FieldGoalsAttempted, TotalPoints, 
   data = NBA1718,
   facets = Position ~ .)
# Out:
# plot without title

# %%
df <- data.frame(gp = factor(rep(letters[1:3], each = 10)),y = rnorm(30))
ggplot(df, aes(x = gp, y = y)) +geom_point()
# Out:
# plot without title

# %%
ggplot(df, aes(x = gp, y = y)) +geom_boxplot()
# Out:
# plot without title

# %%
df$z <- df$y+rnorm(30)

ggplot(df, aes(x = z, y = y)) +geom_point()+facet_grid(gp~.)
ggplot(df, aes(x = z, y = y)) +geom_point()+facet_grid(.~gp)
# Out:
# plot without title
# plot without title

# %%
ggplot(df, aes(x = z, y = y)) +geom_point()+facet_grid(gp~.)+geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(df, aes(x = z, y = y)) +geom_point()+facet_grid(.~gp)+geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(df, aes(x = z, y = y)) +geom_line()+facet_grid(gp~.)
# Out:
# plot without title

# %%
ggplot(df, aes(x = z, y = y, color=gp)) +geom_line()
# Out:
# plot without title
