# %% [markdown]
# <a href="https://colab.research.google.com/github/s10955031/bigdata/blob/main/%E3%80%8C0316_ipynb%E3%80%8D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 列出檔案
system("ls", TRUE)
# Out:
# [1] "20210305動物資料.csv" "sample_data"

# %%
library(readr)

# %%
dataset <- read.csv("20210305動物資料.csv")

# %%
dataset
# Out:
#     A_Name_Ch    A_Summary              A_Keywords            A_AlsoKnown
# 1   大貓熊       請於入園時領取參觀票券 大貓熊;圓仔;團團;圓圓
# 2   國王企鵝                            企鵝；國王企鵝
# 3   黑腳企鵝
# 4   弓角羚羊
# 5   非洲野驢
# 6   單峰駱駝
# 7   雙峰駱駝
# 8   人猿
# 9   大長臂猿
# 10  印度大犀鳥
# 11  亞洲象                              大象
# 12  孟加拉虎                            老虎
# 13  花豹
# 14  馬來熊
# 15  馬來貘
# 16  黑天鵝
# 17  白手長臂猿
# 18  家鴨
# 19  家雞
# 20  家鵝
# 21  天竺鼠
# 22  北美土撥鼠
# 23  羊駝
# 24  長鼻浣熊
# 25  家兔(馴化兔)
# 26  家驢
# 27  迷你馬
# 28  黑蜘蛛猴
# 29  絨鼠
# 30  狐?
# ⋮   ⋮            ⋮                      ⋮                     ⋮
# 335 麝香貓
# 336 食蟹?
# 337 臺灣山羌
# 338 臺灣八哥
# 339 水鹿
# 340 灰袋鼠
# 341 沼林袋鼠
# 342 南方食火雞
# 343 鴯?
# 344 黑掌蜘蛛猴
# 345 水豚
# 346 大食蟻獸
# 347 南美小食蟻獸
# 348 白面捲尾猴
# 349 紅藍吸蜜鸚鵡
# 350 黃腿象龜
# 351 棕蜘蛛猴
# 352 二趾樹獺
# 353 慈鯛
# 354 珍珠魟
# 355 棉頭絹猴
# 356 阿氏夜猴
# 357 小懶猴
# 358 粗尾侏儒狐猴
# 359 蜜熊(未展出)
# 360 金色箭毒蛙
# 361 黃帶箭毒蛙
# 362 迷彩箭毒蛙
# 363 鈷藍箭毒蛙
# 364 象魚
#     A_Geo
# 1   MULTIPOINT ((121.5831587 24.9971109))
# ...

# %%
#預覽前10筆
head(dataset$A_Name_Ch, n=10)
# Out:
#  [1] "大貓熊"     "國王企鵝"   "黑腳企鵝"   "弓角羚羊"   "非洲野驢"
#  [6] "單峰駱駝"   "雙峰駱駝"   "人猿"       "大長臂猿"   "印度大犀鳥"

# %%
tail(dataset$A_Name_Ch, n=10)
# Out:
#  [1] "棉頭絹猴"     "阿氏夜猴"     "小懶猴"       "粗尾侏儒狐猴" "蜜熊(未展出)"
#  [6] "金色箭毒蛙"   "黃帶箭毒蛙"   "迷彩箭毒蛙"   "鈷藍箭毒蛙"   "象魚"

# %%
head(dataset$A_Name_Ch, n=20)
# Out:
#  [1] "大貓熊"     "國王企鵝"   "黑腳企鵝"   "弓角羚羊"   "非洲野驢"
#  [6] "單峰駱駝"   "雙峰駱駝"   "人猿"       "大長臂猿"   "印度大犀鳥"
# [11] "亞洲象"     "孟加拉虎"   "花豹"       "馬來熊"     "馬來貘"
# [16] "黑天鵝"     "白手長臂猿" "家鴨"       "家雞"       "家鵝"

# %%
#搜尋 企鵝
dataset[grepl("企鵝",dataset$A_Name_Ch),]
# Out:
#   A_Name_Ch A_Summary A_Keywords     A_AlsoKnown
# 2 國王企鵝            企鵝；國王企鵝
# 3 黑腳企鵝
#   A_Geo                                 A_Location A_POIGroup A_Name_En
# 2 MULTIPOINT ((121.5907654 24.9931338)) 企鵝館                King Penguin
# 3 MULTIPOINT ((121.5910631 24.9928761)) 企鵝館                Jackass penguin
#   A_Name_Latin            A_Phylum   ⋯ A_pdf02_URL A_Voice01_ALT A_Voice01_URL
# 2 Aptenodytes patagonicus 脊索動物門 ⋯
# 3 Spheniscus demersu      脊索動物門 ⋯
#   A_Voice02_ALT A_Voice02_URL A_Voice03_ALT A_Voice03_URL
# 2
# 3
#   A_Vedio_URL
# 2 https://www.youtube.com/playlist?list=PLWYak5Af5-DuSoWNgHVIi8vH8AlN6Rzg4
# 3 https://www.youtube.com/playlist?list=PLWYak5Af5-Dvty-i1vf2Qi3_pHasXp3LI
#   A_Update  A_CID
# 2 2017/9/29 2
# 3 2017/9/29 3

# %%
#搜尋 蛙
dataset[grepl("蛙",dataset$A_Name_Ch),]
# Out:
#     A_Name_Ch  A_Summary A_Keywords A_AlsoKnown
# 65  莫氏樹蛙
# 73  圓眼珍珠蛙
# 74  飾紋角蛙
# 78  翡翠樹蛙
# 360 金色箭毒蛙
# 361 黃帶箭毒蛙
# 362 迷彩箭毒蛙
# 363 鈷藍箭毒蛙
#     A_Geo                                 A_Location
# 65  MULTIPOINT ((121.5898494 24.9940697)) 兩棲爬蟲動物館
# 73  MULTIPOINT ((121.5898494 24.9940697)) 兩棲爬蟲動物館
# 74  MULTIPOINT ((121.5898494 24.9940697)) 兩棲爬蟲動物館
# 78  MULTIPOINT ((121.5898494 24.9940697)) 兩棲爬蟲動物館
# 360 MULTIPOINT ((121.5832747 24.9958021)) 熱帶雨林室內館(穿山甲館)
# 361 MULTIPOINT ((121.5832747 24.9958021)) 熱帶雨林室內館(穿山甲館)
# 362 MULTIPOINT ((121.5832747 24.9958021)) 熱帶雨林室內館(穿山甲館)
# 363 MULTIPOINT ((121.5832747 24.9958021)) 熱帶雨林室內館(穿山甲館)
#     A_POIGroup     A_Name_En                         A_Name_Latin
# 65  兩棲爬蟲動物館 Moltrecht’s green treefrog        Rhacophorus moltrechti
# 73  兩棲爬蟲動物館 Budgett's frog                    Lepidobatrachus laevis
# 74  兩棲爬蟲動物館 Ornate horned frog                Ceratophrys ornata
# 78  兩棲爬蟲動物館  Emerald green tree frog          Rhacophorus prasinatus
# ...

# %%
#搜尋 虎
dataset[grepl("虎",dataset$A_Name_Ch),]
# Out:
#     A_Name_Ch A_Summary A_Keywords A_AlsoKnown
# 12  孟加拉虎            老虎
# 56  豹紋瞼虎
# 322 石虎
#     A_Geo                                 A_Location     A_POIGroup
# 12  MULTIPOINT ((121.5832372 24.9941782)) 熱帶雨林區
# 56  MULTIPOINT ((121.5898494 24.9940697)) 兩棲爬蟲動物館 兩棲爬蟲動物館
# 322 MULTIPOINT ((121.5809003 24.9971255)) 臺灣動物區
#     A_Name_En     A_Name_Latin                A_Phylum   ⋯ A_pdf02_URL
# 12  Bengal tiger  Panthera tigris tigris      脊索動物門 ⋯
# 56  Leopard gecko Eublepharis macularius      脊索動物門 ⋯
# 322 Leopard Cat   Felis bengalensis chinensis 脊索動物門 ⋯
#     A_Voice01_ALT A_Voice01_URL A_Voice02_ALT A_Voice02_URL A_Voice03_ALT
# 12
# 56
# 322
#     A_Voice03_URL
# 12
# 56
# 322
#     A_Vedio_URL
# 12  https://www.youtube.com/playlist?list=PLWYak5Af5-DuRjK-JM9C47NtwvOcbxsRh
# 56  https://www.youtube.com/playlist?list=PLWYak5Af5-DtsKFP-qcGQh7Zu518rItX7
# 322 https://www.youtube.com/playlist?list=PLWYak5Af5-Dt7HISiObQyDT8kndhjBPmQ
#     A_Update  A_CID
# 12  2017/9/29  11
# ...

# %%
#搜尋 兔
dataset[grepl("兔",dataset$A_Name_Ch),]
# Out:
#    A_Name_Ch    A_Summary A_Keywords A_AlsoKnown A_Geo A_Location A_POIGroup
# 25 家兔(馴化兔)
#    A_Name_En       A_Name_Latin          A_Phylum   ⋯ A_pdf02_URL A_Voice01_ALT
# 25 Domestic Rabbit Oryctolagus cuniculus 脊索動物門 ⋯
#    A_Voice01_URL A_Voice02_ALT A_Voice02_URL A_Voice03_ALT A_Voice03_URL
# 25
#    A_Vedio_URL
# 25 https://www.youtube.com/playlist?list=PLWYak5Af5-Du3KLC8dANN8PeZxIrY1Xo1
#    A_Update  A_CID
# 25 2017/9/29 28

# %%
#搜尋 馬
dataset[grepl("馬",dataset$A_Name_Ch),]
# Out:
#     A_Name_Ch        A_Summary A_Keywords A_AlsoKnown
# 14  馬來熊
# 15  馬來貘
# 27  迷你馬
# 57  馬達加斯加鈍尾蜥
# 188 馬達加斯加蟑螂
# 214 查普曼斑馬
# 216 格利威斑馬
# 225 侏儒河馬
# 227 河馬
# 275 藍額亞馬遜鸚鵡
# 303 黃冠亞馬遜鸚鵡
# 304 黃頸亞馬遜鸚鵡
# 319 蒙古野馬
# 321 馬來長吻鱷
#     A_Geo
# 14  MULTIPOINT ((121.5828868 24.9943343))
# 15  MULTIPOINT ((121.5827151 24.9963569), (121.5832408 24.9947719))
# 27  MULTIPOINT ((121.5824398 24.999554))
# 57  MULTIPOINT ((121.5898494 24.9940697))
# 188 MULTIPOINT ((121.5807004 24.9967402))
# 214 MULTIPOINT ((121.5865181 24.9952463))
# 216 MULTIPOINT ((121.5887457 24.9944271))
# 225 MULTIPOINT ((121.5878731 24.9951075))
# 227 MULTIPOINT ((121.587967 24.9950164))
# 275 MULTIPOINT ((121.5912335 24.99528898))
# 303 MULTIPOINT ((121.5898159 24.9954408))
# 304 MULTIPOINT ((121.5898159 24.9954408))
# 319 MULTIPOINT ((121.589313 24.9936564))
# 321 MULTIPOINT ((121.5830280 24.9964828),(121.5837299 24.9957106), (121.589158 24.9927709))
#     A_Location            A_POIGroup     A_Name_En
# ...

# %%
#計算 目
table(dataset$A_Order)
# Out:
#                                               ?形目    Order Carnivora 食肉目
#                        65                         1                         1
#                    企鵝目                  佛法僧目                    偶蹄目
#                         2                         1                        14
#                   偶蹄目  偶蹄目 Order Artiodactyla                    兔形目
#                         1                         2                         1
#                    半翅目                    囓齒目                    奇蹄目
#                         3                         5                         8
#                    披毛目                    有袋目                    有鱗目
#                         3                         3                        30
#                    杜鵑目                    無尾目                   無尾目
#                         2                         7                         4
#                    燕雀目                    燕魟目                    紅鶴目
# ...

# %%
#計算 科
table(dataset$A_Family)
# Out:
#                                         鴯?科　                  鷲鷹科
#                      67                       1                       1
#                    ??科                     ?科     Family Ursidae 熊科
#                       1                       4                       1
#              二趾樹獺科                人猿人科                  企鵝科
#                       1                       1                       2
#                側頸龜科                僧帽鳥科                    兔科
#                       2                       2                       1
#              吸蜜鸚鵡科                  壁虎科                  夜猴科
#                       1                       1                       1
#                天堂鳥科                天蠶蛾科                寶冠鳥科
#                       1                       2                       1
#         巨猿科Great Ape            巴西骨舌魚科                  慈鯛科
#                       1                       1                       1
# ...

# %%
# 保育等級
table(dataset$A_Conservation)
# Out:
#                                         CITES       CITES Appendix I
#                    291                      1                      2
#          CITES、農委會                     CR               IUCN極危
#                      4                      1                      1
#                     LC                LC,無危         保育類野生動物
#                      5                      2                     11
#          接近受威脅 NT                   易危                易危 VU
#                      1                      1                      6
#   易受威脅。CITES II。            暫無危機 LC                極危 CR
#                      1                     12                      3
#                瀕危 EN         瀕臨絕種保育類 瀕臨絕種保育類野生動物
#                      5                      1                      5
#                   無危                無危 LC 珍貴稀有保育類野生動物
#                      1                      5                      5

# %%
#計算 門
table(dataset$A_Phylum)
# Out:
#                                           ?脊索動物門
#                         41                          1
# Phylum Chordata 脊索動物門                 節肢動物門
#                          1                         73
#                 脊索動物門
#                        248

# %%
#計算 綱
table(dataset$A_Class)
# Out:
#                       Class Mammalia 哺乳綱                兩棲綱
#                    41                     1                     9
#                哺乳綱               哺乳綱                 昆蟲綱
#                    83                     3                    73
#                爬蟲綱              硬骨魚綱              軟骨魚綱
#                    60                     2                     1
#                  鳥綱
#                    91

# %%
install.packages("jsonlite")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library("jsonlite")

# %%
PetData <- jsonlite::fromJSON("https://data.taipei/opendata/datalist/apiAccess?scope=resourceAquire&rid=f4a75ba9-7721-4363-884d-c3820b0b917c")
str(PetData)
# Out:
# List of 1
#  $ result:List of 5
#   ..$ limit  : int 1000
#   ..$ offset : int 0
#   ..$ count  : int 365
#   ..$ sort   : chr ""
#   ..$ results:'data.frame':	365 obs. of  20 variables:
#   .. ..$ AcceptNum      : chr [1:365] "106060601" "106060401" "106060210" "106060207" ...
#   .. ..$ IsSterilization: chr [1:365] "未絕育" "已絕育" "未絕育" "未絕育" ...
#   .. ..$ Name           : chr [1:365] "" "" "俊俊" "小莊" ...
#   .. ..$ Variety        : chr [1:365] "米克斯" "米克斯" "米克斯" "米克斯" ...
#   .. ..$ Age            : chr [1:365] "成年" "成年" "成年" "成年" ...
#   .. ..$ ChildreAnlong  : chr [1:365] "" "" "" "" ...
#   .. ..$ Resettlement   : chr [1:365] "臺北市動物之家 收容編號106060601" "" "臺北市動物之家 收容編號106060210" "臺北市動物之家 收容編號106060207" ...
#   .. ..$ Sex            : chr [1:365] "雄" "雌" "雄" "雄" ...
#   .. ..$ Note           : chr [1:365] "左剪耳 輕微脫水 精神食慾不佳" "" "嗨~~我的名字叫俊俊，希望帥氣的我可以受您的青睞，快來動物之家看看我吧!\n" "哈囉~我的名字叫小莊，目前我在動物之家生活，希望能快快找到，願意認養我的人來帶我回家!!\n" ...
# ...

# %%
head(PetData$result$results)
# Out:
#   AcceptNum IsSterilization Name Variety Age  ChildreAnlong
# 1 106060601 未絕育               米克斯  成年
# 2 106060401 已絕育               米克斯  成年
# 3 106060210 未絕育          俊俊 米克斯  成年
# 4 106060207 未絕育          小莊 米克斯  成年
# 5 106060203 未絕育          好橙 米克斯  成年
# 6 106053107 未絕育          歐雅 米克斯  年輕
#   Resettlement                     Sex
# 1 臺北市動物之家 收容編號106060601 雄
# 2                                  雌
# 3 臺北市動物之家 收容編號106060210 雄
# 4 臺北市動物之家 收容編號106060207 雄
# 5 臺北市動物之家 收容編號106060203 雄
# 6 臺北市動物之家 收容編號106053107 雌
#   Note
# 1 左剪耳 輕微脫水 精神食慾不佳
# 2
# 3 嗨~~我的名字叫俊俊，希望帥氣的我可以受您的青睞，快來動物之家看看我吧!\n
# 4 哈囉~我的名字叫小莊，目前我在動物之家生活，希望能快快找到，願意認養我的人來帶我回家!!\n
# 5 嗨~我的名字叫好橙，害羞的我想要一個溫暖的家，您可以給我這個機會嗎?\n
# 6 大家好~我的名字叫歐雅，我的個性緊張，想帶我回家，要有耐心陪伴我渡過適應期唷!
#   Phone       Reason
# 1 02-87913063 民眾不擬續養
# 2             民眾不擬續養
# 3 02-87913062 動物管制
# 4 02-87913062 動物管制
# 5 02-87913062 動物管制
# 6 02-87913062 動物管制
#   ImageName
# 1 http://163.29.39.183/uploads/images/medium/c0f66294-143c-4406-8714-2e6764352b13.jpg
# ...

# %%
table(PetData$result$results$Reason)
# Out:
#                  動物救援     動物管制 民眾不擬續養     民眾拾獲
#           28          109          155           50           23

# %%
table(PetData$result$results$Sex)
# Out:
#  雄  雌
# 190 175

# %%
table(PetData$result$results$IsSterilization)
# Out:
# 已絕育 未絕育
#    151    214

# %%
table(PetData$result$results$Type)
# Out:
# 其他   犬   貓
#   62  187  116

# %%
head(PetData$result$results, n=10)
# Out:
#    AcceptNum IsSterilization Name Variety Age  ChildreAnlong
# 1  106060601 未絕育               米克斯  成年
# 2  106060401 已絕育               米克斯  成年
# 3  106060210 未絕育          俊俊 米克斯  成年
# 4  106060207 未絕育          小莊 米克斯  成年
# 5  106060203 未絕育          好橙 米克斯  成年
# 6  106053107 未絕育          歐雅 米克斯  年輕
# 7  106052807 未絕育          青茶 米克斯  年輕
# 8  106052604 未絕育          烏莉 米克斯  成年
# 9  106052603 未絕育          安亞 米克斯  年輕
# 10 106052601 已絕育          吉好 米克斯  成年
#    Resettlement                     Sex
# 1  臺北市動物之家 收容編號106060601 雄
# 2                                   雌
# 3  臺北市動物之家 收容編號106060210 雄
# 4  臺北市動物之家 收容編號106060207 雄
# 5  臺北市動物之家 收容編號106060203 雄
# 6  臺北市動物之家 收容編號106053107 雌
# 7  臺北市動物之家 收容編號106052807 雄
# 8  臺北市動物之家 收容編號106052604 雌
# 9  臺北市動物之家 收容編號106052603 雌
# 10 臺北市動物之家 收容編號106052601 雄
#    Note
# 1  左剪耳 輕微脫水 精神食慾不佳
# 2
# 3  嗨~~我的名字叫俊俊，希望帥氣的我可以受您的青睞，快來動物之家看看我吧!\n
# 4  哈囉~我的名字叫小莊，目前我在動物之家生活，希望能快快找到，願意認養我的人來帶我回家!!\n
# 5  嗨~我的名字叫好橙，害羞的我想要一個溫暖的家，您可以給我這個機會嗎?\n
# ...

# %%
tail(PetData$result$results, n=10)
# Out:
#     AcceptNum IsSterilization Name       Variety Age  ChildreAnlong
# 356 103081102 已絕育          蘭D        米克斯  成年
# 357 103081101 已絕育          蘭C        米克斯  年輕
# 358 103022802 已絕育          豬尾巴金金 米克斯  老年
# 359 103022801 已絕育          爺比       米克斯  成年 可
# 360 102123002 未絕育          米老鼠     米克斯  成年
# 361 102111818 未絕育          地瓜       米克斯  年輕
# 362 102010301 已絕育          黑皮       米克斯  年輕 可,太小的較不建議
# 363 101100203 已絕育          柔柔       米克斯  成年 小學以下不建議
# 364 101072602 未絕育          蘭心湄     米克斯  年輕 高中以下不建議
# 365 101061403 已絕育          蘭咪       米克斯  成年 可
#     Resettlement                                                  Sex
# 356 臺北市流浪貓保護協會02-27261079                               雌
# 357 臺北市流浪貓保護協會02-27261079                               雌
# 358 臺北市流浪貓保護協會02-27261079                               雌
# 359 臺北市流浪貓保護協會02-27261079(詢問時直接講貓名,不用講編號)  雄
# 360 臺北市動物之家 收容編號102123002                              雌
# 361 臺北市動物之家 收容編號102111818                              雄
# ...

# %%
table(PetData$result$results$HairType)
# Out:
#   三花   咖啡 咖啡白     棕   棕灰   棕白   棕黑   灰白     白     米   虎斑
#     22      2      1     10      1     14      3      6     23      3     32
# 虎斑白     黃   黃白 黃虎斑     黑   黑棕   黑白 黑虎斑   黑黃
#     21     41     19      3    104     10     39      1     10

# %%
table(PetData$result$results$Phone)
# Out:
#
#                                             15
#                                    02-87913062
#                                              2
# 02 2367-0317                      02 2367-1905
#                                              1
#                                   02-2367-0317
#                                              1
#                                    02-27261079
#                                              2
#                                   02-2738-2130
#                                              2
#                                   02-8791-3062
#                                              5
#                                   02-8791-3063
#                                             22
#                                    02-87913062
#                                            197
#                                   02-87913062
#                                              1
#                                    02-87913063
# ...

# %%
table(PetData$result$results$Name)
# Out:
#                  (深情)款款         Alpha          ARRY          ASSA
#            44             1             1             1             1
#         Bendy       Candies          Copy          Eddy         Greta
#             1             1             1             1             1
#          Judy          Lili           M&M        MaLuco         Marty
#             1             1             1             1             1
#         momo           Nana          Nick          Puma          Rose
#             1             1             1             1             1
#          ROSE       Valerie     Vita/牛牛          一郎          三寶
#             1             1             1             1             1
#          丸子          乖黃          亞瑟          亞當          仔仔
#             1             1             1             1             1
#          仙子          伊芙        佛萊迪          來富          來福
#             1             1             1             1             1
# ...
